# %% [markdown]
# # Gold Stock Price Analysis
# #### Project by Harikrishnan D (23-UST-079)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
# Out:
# /var/folders/64/v_wxynb92f730zd2gdk8jjy00000gn/T/ipykernel_4932/365840009.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("gold.csv")

# %%
df
# Out:
#         Date     Price
# 0    1950-01    34.730
# 1    1950-02    34.730
# 2    1950-03    34.730
# 3    1950-04    34.730
# 4    1950-05    34.730
# ..       ...       ...
# 842  2020-03  1593.764
# 843  2020-04  1680.030
# 844  2020-05  1715.697
# 845  2020-06  1734.032
# 846  2020-07  1840.807
#
# [847 rows x 2 columns]

# %%
df.describe()
# Out:
#              Price
# count   847.000000
# mean    416.556906
# std     453.665313
# min      34.490000
# 25%      35.190000
# 50%     319.622000
# 75%     447.029000
# max    1840.807000

# %%
mean = df["Price"].mean()
mean
# Out:
# 416.5569055489965

# %%
df.plot(kind="scatter", x = 'Date', y = 'Price', s=0.5)
plt.axhline(y=mean, color="red", label="Mean") 
plt.legend(bbox_to_anchor=(0, 1), loc="upper left")

# %%
arr = []
for item in df["Price"].values:
    arr.append(round((item-mean)**2, 2))

arr = np.array(arr)
df["Squared Deviations"]=arr

# %%
arr = []
for item in df["Squared Deviations"].values:
    arr.append(round(math.sqrt(item), 2))

arr = np.array(arr)
df["Variance"]=arr

# %%
df.plot(x="Date", y="Price", color="blue")
df.plot(x="Date", y="Squared Deviations", color="red")
df.plot(x="Date", y="Variance", color="green")
# Out:
# <Axes: xlabel='Date'>
